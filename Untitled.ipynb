# %% [markdown]
# Stack Overflow 2020 Developer Survey: The Data Science Industry Analysis for Data Scientist, Machine learning specialist, Business Analyst or Data Analystm

# %% [markdown]
# All my questions will be surrounding people of colour and the representation as Data Scientists, Machine learning specialists,
# Business Analysts or Data Analysts
#
# Geographic Analysis:
#
# 1.Countries with the highest number of Data Scientists, Machine learning specialists, Business Analysts or Data Analysts?
#
# Demographic Analysis:
#
# 2.What is the age of most Data Scientists, Machine learning,specialists,Business Analysts or Data Analysts?
#
# 3.Highest Level of Formal Education for Data Scientists, Machine learning specialists, Business Analysts or Data Analysts?
#
# The Industrial Analysis:
#
# 4.How many years of experience do Data Scientists, Machine learning specialists,Business Analysts or Data Analysts have?

# %% [markdown]
# Data Understanding
#
# Data Understanding is the first step we are going to take. Indentify, Collect, and Analyze the data these three tasks we       are going to do.

# %% [markdown]
# Import neccessary libraries

# %%
#data analysis

import pandas as pd 
import numpy as np

#data visualisation

import matplotlib.pyplot as plt
import seaborn as sns

#display all coloumns in data frame and all content of the output

pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Import data

# %%
df = pd.read_csv('./developer_survey_2020/survey_results_public.csv')
df.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
#
#   CompFreq  CompTotal  ConvertedComp         Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN         Germany   European Euro
# 1      NaN        NaN            NaN  United Kingdom  Pound sterling
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
#
#                                                                DevType  \
# 0  Developer, desktop or enterprise applications;Developer, full-stack
# 1                              Developer, full-stack;Developer, mobile
#
#                                            EdLevel  \
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %% [markdown]
# Identify
#
# Identify the role as Data Scientist or Machine learning specialists or Data or business analyst. And make a new Data Frame for the categories selected.

# %%
ds = df[df['DevType']== ('Data scientist or machine learning specialist' or 'Data or business analyst')]
ds.head(2)
# Out:
#      Respondent  \
# 386         388
# 506         508
#
#                                                                         MainBranch  \
# 386  I am not primarily a developer, but I write code sometimes as part of my work
# 506  I am not primarily a developer, but I write code sometimes as part of my work
#
#     Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 386      Yes  NaN         15      NaN        NaN            NaN
# 506      Yes  NaN         13   Yearly   250000.0       250000.0
#
#            Country          CurrencyDesc CurrencySymbol  \
# 386  United States  United States dollar            USD
# 506  United States  United States dollar            USD
#
#        DatabaseDesireNextYear        DatabaseWorkedWith  \
# 386  Elasticsearch;PostgreSQL  MongoDB;MySQL;PostgreSQL
# 506        MongoDB;PostgreSQL                   MongoDB
#
#                                            DevType  \
# 386  Data scientist or machine learning specialist
# ...

# %%
ds.Ethnicity.unique()
# Out:
# array([nan, 'White or of European descent', 'South Asian',
#        'Southeast Asian', 'Middle Eastern', 'Black or of African descent',
#        'East Asian',
#        'Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Multiracial',
#        'Multiracial', 'Hispanic or Latino/a/x',
#        'Middle Eastern;White or of European descent',
#        'Black or of African descent;Middle Eastern',
#        'White or of European descent;Biracial;Southeast Asian',
#        'East Asian;White or of European descent',
#        'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian',
#        'Black or of African descent;White or of European descent',
#        'Hispanic or Latino/a/x;White or of European descent',
#        'Black or of African descent;Hispanic or Latino/a/x'], dtype=object)

# %%
pd.DataFrame(ds['Ethnicity'].dropna().str.split(';').to_list()).stack().value_counts()
# Out:
# White or of European descent                                                        187
# South Asian                                                                          44
# Middle Eastern                                                                       19
# Southeast Asian                                                                      17
# Hispanic or Latino/a/x                                                               13
# Black or of African descent                                                          12
# East Asian                                                                           12
# Multiracial                                                                           6
# Biracial                                                                              3
# Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)      2
# dtype: int64

# %%
#make a new dataframe for people of colour

dsc = ds[ds['Ethnicity'] != 'White or of European descent']

dsc.head(2)
# Out:
#      Respondent  \
# 386         388
# 506         508
#
#                                                                         MainBranch  \
# 386  I am not primarily a developer, but I write code sometimes as part of my work
# 506  I am not primarily a developer, but I write code sometimes as part of my work
#
#     Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 386      Yes  NaN         15      NaN        NaN            NaN
# 506      Yes  NaN         13   Yearly   250000.0       250000.0
#
#            Country          CurrencyDesc CurrencySymbol  \
# 386  United States  United States dollar            USD
# 506  United States  United States dollar            USD
#
#        DatabaseDesireNextYear        DatabaseWorkedWith  \
# 386  Elasticsearch;PostgreSQL  MongoDB;MySQL;PostgreSQL
# 506        MongoDB;PostgreSQL                   MongoDB
#
#                                            DevType  \
# 386  Data scientist or machine learning specialist
# ...

# %%
dsc.shape
# Out:
# (191, 61)

# %%
def plot_graph(data_source, xlabel, ylabel, title):
   
    """
    Description: This function can be used to plot a bar graph

    Arguments:
        data_source: the data source we're going to plot 
        xlabel: the x axis label
        ylabel: the y axis label
        title: the title of the graph

    Returns:
        Bar graph
    """
    
    #creating x and y axis
    x = data_source.index
    y = data_source/country.sum()*100
    
    #create and display plot graph
    f, ax1 = plt.subplots(figsize=(15,5))
    ax1.set(xlabel=xlabel, ylabel=ylabel, title=title)
    sns.barplot(x=x, y=y, ax=ax1)
    plt.show()

# %% [markdown]
# Since I'll be plotting multiple graphs I've decided to create a function to do this instead of writing out the same lines of code multiple times.

# %% [markdown]
# Geographic Analysis:
#
# 1.Countries with the highest number of Data Scientists, Machine learning specialists, Business Analysts or Data Analysts?

# %%
#listing all the countris
country = dsc.Country.value_counts()

plot_graph(country, 'Countries', 'Percentages %'," Top countries with data scientists, machine learning specialits, data analysts and business analysts of color")

# %%
#top 10 countries #chose to do top 10 because last dataset was too big
country = dsc.Country.value_counts().head(10)

plot_graph(country, 'Countries', 'Percantages %', " Top countries with data scientists, machine learning specialits, data analysts and business analysts of color")

# %% [markdown]
# In the image above you can see that india hosts the majority of data scientists, machine learning specialits, data analysts and business analysts of people color, with the United States coming in close second. The rest of the countries make up a small percentage of the total populus with most being well below 10 %.

# %% [markdown]
# Demographic Analysis:
#
# 2.What is the age of most Data Scientists, Machine learning specialists,Business Analysts or Data Analysts?

# %%
#creating dataset to graph
age = pd.DataFrame(dsc['Age'].dropna().astype(int).to_list()).stack()
age = age.value_counts()

plot_graph(age, 'Age', 'Percentages', 'Age of the Data Scientists, Machine learning,specialists,Business Analysts or Data Analysts of colour')

# %% [markdown]
# From the data gathered we can see that the majority of the population in these fields are between 30 and 31 years old, with the largest age group being 26 year olds.

# %% [markdown]
# Throughout the document you'll see that I tend have dropped the 'NA' values from a few of my data sets, I did this because I was not planning on running any ML Models on them but merely doing a statistical anyalsis on the data sets. Since the missing values making up a very small portion of my data sets, i was still able to do a analysis and draw conclusions on the remaining data set.

# %% [markdown]
# 3.Highest Level of Formal Education for Data Scientists, Machine learning specialists, Business Analysts or Data Analysts?

# %%
#create dataset to graph
formal_education = pd.DataFrame(ds['EdLevel'].dropna().str.strip().tolist()).stack()
formal_education= formal_education.value_counts()

#getting levels of education and percentages
y = formal_education.index
x = formal_education/formal_education.sum()*100

#create and plot graph
f,ax1 = plt.subplots(figsize=(5,10))
ax1.set(xlabel = 'Percentage %', ylabel = 'Formal Education', 
        title = "Highest level of education for Data Scientists, Machine learning specialists, Business Analysts or Data Analysts of colour")
sns.barplot(x=x, y=y, ax=ax1);

# %% [markdown]
# The majority of the populus in the field have a masters degree and following in close second are people with a Bachelors.

# %% [markdown]
# The reason I didn't use the function in the graph above is because I changed the axis on this graph to better accommodate the labels.

# %% [markdown]
# The Industrial Analysis:
#
# 4.How many years of experience do Data Scientists, Machine learning specialists,Business Analysts or Data Analysts have?

# %%
#Need to replace some entries in the "YearsCode" column due to them being strings.
years_coding = dsc['YearsCode'].replace({'Less than 1 year': '<1', 'More than 50 years': '>50'}).value_counts()

plot_graph(years_coding, 'Coding experience in years', 'Percentage %', "Overall coding experience as a Data Scientists, Machine learning specialists,Business Analysts or Data Analysts of color")

# %% [markdown]
# From the image above we can see that majority of the populus has less than 10 years of experience coding.
